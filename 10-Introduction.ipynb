# %% [markdown]
# # Introduction
# Asim Zia (15-20 minutes)
# Feel free to use Powerpoint slides for your section
# More Text Here
#
# ## HABs Forecasting Overview
# ## IAM Overview
# (Pat will cover more in depth)
# ## Emulators
# ### Why use an Emulator
# So we can do more scenarios... Forecast Elasticity Experiments
# ### Examples
#
# Markdown syntax to embed an image:
# ```
# ![Our Training Data Workflow](images/DataWorkflowTraining.png "Our Training Data Workflow")
# ```
#
# Markdown syntax for a link:
# ```
# [webinar by Vetria Byrd of Purdue University](https://sites.google.com/njit.edu/cds-exchange/webinar-series/data-visualization)
# ```

# %% [markdown]
# # **Why Emulators Are Needed**
# - Environmental systems are controlled by many interacting drivers:
#   - Climate Conditions
#   - Hydrology
#   - Land Use
#   - Nutrient Loading
#   - Management and Policy Scenarios
# - Process-based models are useful because they simulate these coupled human-natural interactions.
# - These simulations help us understand:
#   - Which drivers influence water quality outcomes?
#   - How do environmental and policy scenarios affect chlorophyll-a?
#   - Are there distant or indirect drivers linked to local outcomes?
# ## **Main Challenge**
# - Detailed process-based simulations can be computationally expensive.
# - This makes it difficult to repeatedly:
#   - explore many scenarios,
#   - compare driver sensitivities,
#   - test policy interventions,
#   - generate interpretation plots,
#   - run uncertainty or stability analysis.
# ## **Emulator-Based Solution**
# - A machine-learned emulator is a fast surrogate model.
# - It is trained to approximate the outputs of a more complex simulator.
# - The emulator does **not** replace the simulator.
# - Instead, it helps analyze simulator behavior more efficiently.
